# %%
#!pip install smolagents
#!pip install gradio-client
# Out:
# Collecting gradio-client
#   Downloading gradio_client-1.7.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: fsspec in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from gradio-client) (2024.12.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from gradio-client) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from gradio-client) (0.28.1)
# Requirement already satisfied: packaging in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from gradio-client) (24.2)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from gradio-client) (4.12.2)
# Collecting websockets<15.0,>=10.0 (from gradio-client)
#   Downloading websockets-14.2-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: anyio in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from httpx>=0.24.1->gradio-client) (4.6.2)
# Requirement already satisfied: certifi in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from httpx>=0.24.1->gradio-client) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from httpx>=0.24.1->gradio-client) (1.0.2)
# Requirement already satisfied: idna in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from httpx>=0.24.1->gradio-client) (3.7)
# Requirement already satisfied: sniffio in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from httpx>=0.24.1->gradio-client) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio-client) (0.14.0)
# Requirement already satisfied: filelock in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from huggingface-hub>=0.19.3->gradio-client) (3.17.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from huggingface-hub>=0.19.3->gradio-client) (6.0.2)
# Requirement already satisfied: requests in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from huggingface-hub>=0.19.3->gradio-client) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from huggingface-hub>=0.19.3->gradio-client) (4.67.1)
# Requirement already satisfied: colorama in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.19.3->gradio-client) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from anyio->httpx>=0.24.1->gradio-client) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio-client) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rsagadam\appdata\local\anaconda3\envs\py310\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio-client) (2.3.0)
# Downloading gradio_client-1.7.0-py3-none-any.whl (321 kB)
# Downloading websockets-14.2-cp310-cp310-win_amd64.whl (164 kB)
# Installing collected packages: websockets, gradio-client
# Successfully installed gradio-client-1.7.0 websockets-14.2

# %%
from smolagents import Tool

# %%
image_generation_tool = Tool.from_space(
    "black-forest-labs/FLUX.1-schnell",
    name="image_generator",
    description="Generate an image from a prompt"
)

x = image_generation_tool("a beautiful brown lady in aethetic indian background, temples and flowers ")
# Out:
# Loaded as API: https://black-forest-labs-flux-1-schnell.hf.space ✔
# Since `api_name` was not defined, it was automatically set to the first available API: `/infer`.

# %%
from urllib.request import urlretrieve

from PIL import Image

background = Image.open(x)
background
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1024x1024>
